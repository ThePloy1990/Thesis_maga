# %%
# Взяты у Yahoo через функцию get_top_sp500_tickers, функция работает долго, так что я создал список
top_20_symbols = ['AAPL','MSFT','NVDA','AMZN','GOOGL','GOOG','META','BRK-B','AVGO',
                  'TSLA','WMT','LLY','JPM','V','UNH','MA','XOM','COST','NFLX','PG']

symbols = [
        'AAPL', 'MSFT', 'AMZN', 'GOOG', 'META', 'TSLA', 'NVDA', 'JPM', 'JNJ', 'V',
        'WMT', 'PG', 'MA', 'DIS', 'HD', 'BAC', 'CMCSA', 'ADBE', 'PFE',
        'XOM', 'VZ', 'CSCO', 'KO', 'PEP', 'INTC', 'NFLX', 'MRK', 'ABT', 'T',
        'CRM', 'ABBV', 'COST', 'TMO', 'AVGO', 'ACN', 'QCOM', 'DHR', 'MDT', 'NKE',
        'MCD', 'BMY', 'UNH', 'LIN', 'AMD', 'PM', 'HON', 'LOW', 'SBUX', 'UPS',
        'IBM', 'RTX', 'CVX', 'ORCL', 'TXN', 'CAT', 'GS', 'AMGN', 'BA', 'MMM',
        'DE', 'GE', 'NOW', 'PLD', 'SPGI', 'INTU', 'ISRG', 'SYK', 'BLK', 'ADI',
        'GILD', 'LMT', 'MDLZ', 'BKNG', 'AMT', 'ZTS', 'REGN', 'SCHW', 'CI', 'AXP',
        'MO', 'TJX', 'VRTX', 'BDX', 'MU', 'CSX', 'CME', 'ADP',
        'SNPS', 'TMUS', 'EQIX', 'ILMN', 'KLAC', 'PANW', 'CDNS', 'MAR', 'MCO', 'AON'
    ]


sp500_tickers = [
    'MMM', 'AOS', 'ABT', 'ABBV', 'ACN', 'ADBE', 'AMD', 'AES', 'AFL', 'A', 
    'APD', 'AKAM', 'ALK', 'ALB', 'ARE', 'ALGN', 'ALLE', 'LNT', 'ALL', 'GOOGL', 
    'GOOG', 'MO', 'AMZN', 'AMCR', 'AEE', 'AAL', 'AEP', 'AXP', 'AIG', 'AMT', 
    'AWK', 'AMP', 'ABC', 'AME', 'AMGN', 'APH', 'ADI', 'ANSS', 'AON', 'APA', 
    'AAPL', 'AMAT', 'APTV', 'ACGL', 'ANET', 'AJG', 'AIZ', 'T', 'ATO', 'ADSK', 
    'AZO', 'AVB', 'AVY', 'BKR', 'BALL', 'BAC', 'BBWI', 'BAX', 'BDX', 'WRB', 
    'BRK.B', 'BBY', 'BIO', 'TECH', 'BIIB', 'BLK', 'BK', 'BA', 'BKNG', 'BWA', 
    'BXP', 'BSX', 'BMY', 'AVGO', 'BR', 'BRO', 'BF.B', 'CHRW', 'CDNS', 'CZR', 
    'CPB', 'COF', 'CAH', 'KMX', 'CCL', 'CARR', 'CTLT', 'CAT', 'CBOE', 'CBRE', 
    'CDW', 'CE', 'CNC', 'CNP', 'CDAY', 'CF', 'CRL', 'SCHW', 'CHTR', 'CVX', 
    'CMG', 'CB', 'CHD', 'CI', 'CINF', 'CTAS', 'CSCO', 'C', 'CFG', 'CLX', 
    'CME', 'CMS', 'KO', 'CTSH', 'CL', 'CMCSA', 'CMA', 'CAG', 'COP', 'ED', 
    'STZ', 'CPRT', 'GLW', 'CTVA', 'COST', 'CTRA', 'CCI', 'CSX', 'CMI', 'CVS', 
    'DHI', 'DHR', 'DRI', 'DVA', 'DE', 'DAL', 'XRAY', 'DVN', 'DXCM', 'FANG', 
    'DLR', 'DFS', 'DIS', 'DG', 'DLTR', 'D', 'DPZ', 'DOV', 'DOW', 'DTE', 
    'DUK', 'DD', 'DXC', 'EMN', 'ETN', 'EBAY', 'ECL', 'EIX', 'EW', 'EA', 
    'ELV', 'LLY', 'EMR', 'ENPH', 'ETR', 'EOG', 'EPAM', 'EQT', 'EFX', 'EQIX', 
    'EQR', 'ESS', 'EL', 'ETSY', 'EG', 'EVRG', 'ES', 'EXC', 'EXPE', 'EXPD', 
    'EXR', 'XOM', 'FFIV', 'FDS', 'FAST', 'FRT', 'FDX', 'FITB', 'FSLR', 'FE', 
    'FIS', 'FISV', 'FLT', 'FMC', 'F', 'FTNT', 'FTV', 'FOXA', 'FOX', 'BEN', 
    'FCX', 'GRMN', 'IT', 'GE', 'GEN', 'GNRC', 'GD', 'GIS', 'GM', 'GPC', 
    'GILD', 'GL', 'GPN', 'GS', 'HAL', 'HIG', 'HAS', 'HCA', 'PEAK', 'HSIC', 
    'HES', 'HPE', 'HLT', 'HOLX', 'HD', 'HON', 'HRL', 'HST', 'HWM', 'HPQ', 
    'HUM', 'HBAN', 'HII', 'IBM', 'IEX', 'IDXX', 'ITW', 'ILMN', 'INCY', 'IR', 
    'INTC', 'ICE', 'IP', 'IPG', 'IFF', 'INTU', 'ISRG', 'IVZ', 'INVH', 'IQV', 
    'IRM', 'JBHT', 'JKHY', 'J', 'JNJ', 'JCI', 'JPM', 'JNPR', 'K', 'KDP', 
    'KEY', 'KEYS', 'KMB', 'KIM', 'KMI', 'KLAC', 'KHC', 'KR', 'LHX', 'LH', 
    'LRCX', 'LW', 'LVS', 'LDOS', 'LEN', 'LNC', 'LIN', 'LYV', 'LKQ', 'LMT', 
    'L', 'LOW', 'LUMN', 'LYB', 'MTB', 'MRO', 'MPC', 'MKTX', 'MAR', 'MMC', 
    'MLM', 'MAS', 'MA', 'MTCH', 'MKC', 'MCD', 'MCK', 'MDT', 'MRK', 'META', 
    'MET', 'MTD', 'MGM', 'MCHP', 'MU', 'MSFT', 'MAA', 'MRNA', 'MHK', 'MOH', 
    'TAP', 'MDLZ', 'MPWR', 'MNST', 'MCO', 'MS', 'MOS', 'MSI', 'MSCI', 'NDAQ', 
    'NTAP', 'NFLX', 'NWL', 'NEM', 'NWSA', 'NWS', 'NEE', 'NKE', 'NI', 'NDSN', 
    'NSC', 'NTRS', 'NOC', 'NCLH', 'NRG', 'NUE', 'NVDA', 'NVR', 'NXPI', 'ORLY', 
    'OXY', 'ODFL', 'OMC', 'ON', 'OKE', 'ORCL', 'OGN', 'OTIS', 'PCAR', 'PKG', 
    'PANW', 'PARA', 'PH', 'PAYX', 'PAYC', 'PYPL', 'PNR', 'PEP', 'PFE', 'PCG', 
    'PM', 'PSX', 'PNW', 'PXD', 'PNC', 'POOL', 'PPG', 'PPL', 'PFG', 'PG', 
    'PGR', 'PLD', 'PRU', 'PEG', 'PTC', 'PSA', 'PHM', 'QRVO', 'PWR', 'QCOM', 
    'DGX', 'RL', 'RJF', 'RTX', 'O', 'REG', 'REGN', 'RF', 'RSG', 'RMD', 'RVTY', 
    'RHI', 'ROK', 'ROL', 'ROP', 'ROST', 'RCL', 'SPGI', 'CRM', 'SBAC', 'SLB', 
    'STX', 'SEE', 'SRE', 'NOW', 'SHW', 'SPG', 'SWKS', 'SJM', 'SNA', 'SEDG', 
    'SO', 'LUV', 'SWK', 'SBUX', 'STT', 'STLD', 'STE', 'SYK', 'SYF', 'SNPS', 
    'SYY', 'TMUS', 'TROW', 'TTWO', 'TPR', 'TRGP', 'TGT', 'TEL', 'TDY', 'TFX', 
    'TER', 'TSLA', 'TXN', 'TXT', 'TMO', 'TJX', 'TSCO', 'TT', 'TDG', 'TRV', 
    'TRMB', 'TFC', 'TYL', 'TSN', 'USB', 'UDR', 'ULTA', 'UNP', 'UAL', 'UPS', 
    'URI', 'UNH', 'UHS', 'VLO', 'VTR', 'VRSN', 'VRSK', 'VZ', 'VRTX', 'VFC', 
    'VTRS', 'VICI', 'V', 'VMC', 'WAB', 'WBA', 'WMT', 'WBD', 'WM', 'WAT', 
    'WEC', 'WFC', 'WELL', 'WST', 'WDC', 'WRK', 'WY', 'WHR', 'WMB', 'WTW', 
    'GWW', 'WYNN', 'XEL', 'XYL', 'YUM', 'ZBRA', 'ZBH', 'ZION', 'ZTS'
]

# %%
pip install yfinance
# Out:
# Collecting yfinance
#   Downloading yfinance-0.2.61-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\user\documents\diplom\.venv\lib\site-packages (from yfinance) (1.5.3)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\user\documents\diplom\.venv\lib\site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in c:\users\user\documents\diplom\.venv\lib\site-packages (from yfinance) (2.32.3)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Using cached multitasking-0.0.11-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\user\documents\diplom\.venv\lib\site-packages (from yfinance) (4.3.7)
# Requirement already satisfied: pytz>=2022.5 in c:\users\user\documents\diplom\.venv\lib\site-packages (from yfinance) (2025.2)
# Collecting frozendict>=2.3.4 (from yfinance)
#   Using cached frozendict-2.4.6-cp39-cp39-win_amd64.whl.metadata (23 kB)
# Collecting peewee>=3.16.2 (from yfinance)
#   Downloading peewee-3.18.1.tar.gz (3.0 MB)
#      ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#      --- ------------------------------------ 0.3/3.0 MB ? eta -:--:--
#      ----------------- ---------------------- 1.3/3.0 MB 4.8 MB/s eta 0:00:01
#      ----------------- ---------------------- 1.3/3.0 MB 4.8 MB/s eta 0:00:01
#      --------------------------- ------------ 2.1/3.0 MB 3.1 MB/s eta 0:00:01
#      ---------------------------------------- 3.0/3.0 MB 3.3 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting beautifulsoup4>=4.11.1 (from yfinance)
#   Downloading beautifulsoup4-4.13.4-py3-none-any.whl.metadata (3.8 kB)
# Collecting curl_cffi>=0.7 (from yfinance)
#   Downloading curl_cffi-0.11.1-cp39-abi3-win_amd64.whl.metadata (15 kB)
# Collecting protobuf>=3.19.0 (from yfinance)
#   Downloading protobuf-6.31.0-cp39-cp39-win_amd64.whl.metadata (593 bytes)
# Collecting websockets>=13.0 (from yfinance)
#   Downloading websockets-15.0.1-cp39-cp39-win_amd64.whl.metadata (7.0 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4>=4.11.1->yfinance)
#   Downloading soupsieve-2.7-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\user\documents\diplom\.venv\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.13.2)
# Collecting cffi>=1.12.0 (from curl_cffi>=0.7->yfinance)
#   Downloading cffi-1.17.1-cp39-cp39-win_amd64.whl.metadata (1.6 kB)
# Requirement already satisfied: certifi>=2024.2.2 in c:\users\user\documents\diplom\.venv\lib\site-packages (from curl_cffi>=0.7->yfinance) (2025.4.26)
# Collecting pycparser (from cffi>=1.12.0->curl_cffi>=0.7->yfinance)
#   Downloading pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\user\documents\diplom\.venv\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\user\documents\diplom\.venv\lib\site-packages (from python-dateutil>=2.8.1->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\documents\diplom\.venv\lib\site-packages (from requests>=2.31->yfinance) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\documents\diplom\.venv\lib\site-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\documents\diplom\.venv\lib\site-packages (from requests>=2.31->yfinance) (1.26.20)
# Downloading yfinance-0.2.61-py2.py3-none-any.whl (117 kB)
# Downloading beautifulsoup4-4.13.4-py3-none-any.whl (187 kB)
# Downloading curl_cffi-0.11.1-cp39-abi3-win_amd64.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 7.4 MB/s eta 0:00:00
# Downloading cffi-1.17.1-cp39-cp39-win_amd64.whl (181 kB)
# Using cached frozendict-2.4.6-cp39-cp39-win_amd64.whl (37 kB)
# Using cached multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Downloading protobuf-6.31.0-cp39-cp39-win_amd64.whl (435 kB)
# Downloading soupsieve-2.7-py3-none-any.whl (36 kB)
# Downloading websockets-15.0.1-cp39-cp39-win_amd64.whl (176 kB)
# Downloading pycparser-2.22-py3-none-any.whl (117 kB)
# Building wheels for collected packages: peewee
#   Building wheel for peewee (pyproject.toml): started
#   Building wheel for peewee (pyproject.toml): finished with status 'done'
#   Created wheel for peewee: filename=peewee-3.18.1-py3-none-any.whl size=139100 sha256=25d6c92aac7976df259e043ab38e77b6e5e1f94def97f5e0634ddb3d67945ed7
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\e7\09\87\1f1a87eb25af98d0a1f60ef184a9779d81c6a2e8d28bc67d7f
# Successfully built peewee
# Installing collected packages: peewee, multitasking, websockets, soupsieve, pycparser, protobuf, frozendict, cffi, beautifulsoup4, curl_cffi, yfinance
#
#    ----------------------------------------  0/11 [peewee]
#    ----------------------------------------  0/11 [peewee]
#    ----------------------------------------  0/11 [peewee]
#    ----------------------------------------  0/11 [peewee]
#    ----------------------------------------  0/11 [peewee]
#    ----------------------------------------  0/11 [peewee]
#    ------- --------------------------------  2/11 [websockets]
#    ------- --------------------------------  2/11 [websockets]
#    ------- --------------------------------  2/11 [websockets]
#    ------- --------------------------------  2/11 [websockets]
#    ------- --------------------------------  2/11 [websockets]
#    ------- --------------------------------  2/11 [websockets]
#    ------- --------------------------------  2/11 [websockets]
#    ------- --------------------------------  2/11 [websockets]
#    ------- --------------------------------  2/11 [websockets]
#    ------- --------------------------------  2/11 [websockets]
#    ------- --------------------------------  2/11 [websockets]
#    ------- --------------------------------  2/11 [websockets]
#    ------- --------------------------------  2/11 [websockets]
#    ------- --------------------------------  2/11 [websockets]
#    ------- --------------------------------  2/11 [websockets]
#    ---------- -----------------------------  3/11 [soupsieve]
#    ---------- -----------------------------  3/11 [soupsieve]
#    ---------- -----------------------------  3/11 [soupsieve]
#    -------------- -------------------------  4/11 [pycparser]
#    -------------- -------------------------  4/11 [pycparser]
#    -------------- -------------------------  4/11 [pycparser]
#    -------------- -------------------------  4/11 [pycparser]
#    -------------- -------------------------  4/11 [pycparser]
#    -------------- -------------------------  4/11 [pycparser]
#    ------------------ ---------------------  5/11 [protobuf]
#    ------------------ ---------------------  5/11 [protobuf]
#    ------------------ ---------------------  5/11 [protobuf]
#    ------------------ ---------------------  5/11 [protobuf]
#    ------------------ ---------------------  5/11 [protobuf]
#    ------------------ ---------------------  5/11 [protobuf]
#    ------------------ ---------------------  5/11 [protobuf]
#    ------------------ ---------------------  5/11 [protobuf]
#    ------------------ ---------------------  5/11 [protobuf]
#    ------------------ ---------------------  5/11 [protobuf]
#    ------------------ ---------------------  5/11 [protobuf]
#    ------------------ ---------------------  5/11 [protobuf]
#    ------------------ ---------------------  5/11 [protobuf]
#    ------------------ ---------------------  5/11 [protobuf]
#    ------------------ ---------------------  5/11 [protobuf]
#    ------------------ ---------------------  5/11 [protobuf]
#    ------------------ ---------------------  5/11 [protobuf]
#    ------------------ ---------------------  5/11 [protobuf]
#    ------------------ ---------------------  5/11 [protobuf]
#    --------------------- ------------------  6/11 [frozendict]
#    ------------------------- --------------  7/11 [cffi]
#    ------------------------- --------------  7/11 [cffi]
#    ------------------------- --------------  7/11 [cffi]
#    ------------------------- --------------  7/11 [cffi]
#    ------------------------- --------------  7/11 [cffi]
#    ------------------------- --------------  7/11 [cffi]
#    ----------------------------- ----------  8/11 [beautifulsoup4]
#    ----------------------------- ----------  8/11 [beautifulsoup4]
#    ----------------------------- ----------  8/11 [beautifulsoup4]
#    ----------------------------- ----------  8/11 [beautifulsoup4]
#    ----------------------------- ----------  8/11 [beautifulsoup4]
#    ----------------------------- ----------  8/11 [beautifulsoup4]
#    ----------------------------- ----------  8/11 [beautifulsoup4]
#    ----------------------------- ----------  8/11 [beautifulsoup4]
#    ----------------------------- ----------  8/11 [beautifulsoup4]
#    ----------------------------- ----------  8/11 [beautifulsoup4]
#    -------------------------------- -------  9/11 [curl_cffi]
#    -------------------------------- -------  9/11 [curl_cffi]
#    -------------------------------- -------  9/11 [curl_cffi]
#    -------------------------------- -------  9/11 [curl_cffi]
#    -------------------------------- -------  9/11 [curl_cffi]
#    ------------------------------------ --- 10/11 [yfinance]
#    ------------------------------------ --- 10/11 [yfinance]
#    ------------------------------------ --- 10/11 [yfinance]
#    ------------------------------------ --- 10/11 [yfinance]
#    ------------------------------------ --- 10/11 [yfinance]
#    ------------------------------------ --- 10/11 [yfinance]
#    ------------------------------------ --- 10/11 [yfinance]
#    ------------------------------------ --- 10/11 [yfinance]
#    ------------------------------------ --- 10/11 [yfinance]
#    ------------------------------------ --- 10/11 [yfinance]
#    ------------------------------------ --- 10/11 [yfinance]
#    ---------------------------------------- 11/11 [yfinance]
#
# Successfully installed beautifulsoup4-4.13.4 cffi-1.17.1 curl_cffi-0.11.1 frozendict-2.4.6 multitasking-0.0.11 peewee-3.18.1 protobuf-6.31.0 pycparser-2.22 soupsieve-2.7 websockets-15.0.1 yfinance-0.2.61
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf
import pandas as pd
from datetime import datetime, timedelta
import time
#from prophet import Prophet

def get_top_sp500_tickers(top_n=20):
    """Альтернативная версия с получением текущей капитализации через yfinance"""
    try:
        # Получаем базовый список с Wikipedia
        url = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'
        tables = pd.read_html(url)
        sp500_table = tables[0]
        tickers = sp500_table['Symbol'].tolist()
        tickers = [ticker.replace('.', '-') for ticker in tickers]

        # Получаем текущую капитализацию для каждого тикера
        market_caps = {}
        for ticker in tickers:
            try:
                stock = yf.Ticker(ticker)
                market_cap = stock.info.get('marketCap', 0)
                market_caps[ticker] = market_cap
                time.sleep(0.1)  # Чтобы не получить бан от Yahoo
            except:
                continue

        # Сортируем по капитализации и берем топ N
        sorted_tickers = sorted(market_caps.keys(), key=lambda x: market_caps[x], reverse=True)
        return sorted_tickers[:top_n]

    except Exception as e:
        print(f"Ошибка: {e}")
        return None

def download_and_transform_data(tickers, period="10y"):
    """Загружает данные и преобразует в нужный формат"""
    try:
        data = yf.download(
            tickers=tickers,
            period=period,
            interval="1d",
            group_by='ticker',
            progress=True,
            threads=True
        )

        # Собираем данные в список DataFrame'ов
        frames = []
        for ticker in tickers:
            if ticker in data:
                # Создаем копию данных для текущего тикера
                df = data[ticker].copy()
                # Сбрасываем индекс, чтобы 'Date' стал обычным столбцом
                df = df.reset_index()
                # Добавляем столбец с тикером
                df['symbol'] = ticker
                frames.append(df)

        if not frames:
            return pd.DataFrame()

        # Объединяем все DataFrame'ы
        combined = pd.concat(frames, ignore_index=True)

        # Сортируем по тикеру и дате
        combined = combined.sort_values(['symbol', 'Date'])

        # Создаем целевую переменную (годовая доходность)
        combined['future_price'] = combined.groupby('symbol')['Close'].shift(-252)
        combined['future_month_price'] = combined.groupby('symbol')['Close'].shift(-20)
        # В месяце +- 20 торговых дней
        combined['annual_return'] = (combined['future_price'] / combined['Close']) - 1
        combined['month_return'] = (combined['future_month_price'] / combined['Close']) - 1

        return combined

    except Exception as e:
        print(f"Ошибка при загрузке данных: {e}")
        return pd.DataFrame()

    except Exception as e:
        print(f"Ошибка при загрузке и преобразовании данных: {e}")
        return pd.DataFrame()

def save_to_csv(data, filename_prefix="sp500_ml_data"):
    """Сохраняет данные в CSV файл"""
    if data is None or data.empty:
        print("Нет данных для сохранения")
        return

    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    filename = f"data/{filename_prefix}_{timestamp}.csv"
    data.to_csv(filename, index=False)
    print(f"Данные сохранены в файл: {filename}")

def main(top_tickers=sp500_tickers):
    print("Получаем топ 20 акций S&P 500 по капитализации...")
    if top_tickers == []:
        top_tickers = get_top_sp500_tickers(top_n=20)

    if not top_tickers:
        print("Не удалось получить список акций. Завершение работы.")
        return

    print(f"Топ 20 акций по капитализации: {', '.join(top_tickers)}")

    print("Загружаем и преобразуем исторические данные...")
    stock_data = download_and_transform_data(top_tickers, period="10y")

    if not stock_data.empty:
        print("\nУспешно загружены и преобразованы данные:")
        print(stock_data.head())

        save_to_csv(stock_data, "sp500_ml_ready")
    else:
        print("Не удалось загрузить данные или данные пусты.")

# %%
main()
# Out:
# Получаем топ 20 акций S&P 500 по капитализации...
# Топ 20 акций по капитализации: MMM, AOS, ABT, ABBV, ACN, ADBE, AMD, AES, AFL, A, APD, AKAM, ALK, ALB, ARE, ALGN, ALLE, LNT, ALL, GOOGL, GOOG, MO, AMZN, AMCR, AEE, AAL, AEP, AXP, AIG, AMT, AWK, AMP, ABC, AME, AMGN, APH, ADI, ANSS, AON, APA, AAPL, AMAT, APTV, ACGL, ANET, AJG, AIZ, T, ATO, ADSK, AZO, AVB, AVY, BKR, BALL, BAC, BBWI, BAX, BDX, WRB, BRK.B, BBY, BIO, TECH, BIIB, BLK, BK, BA, BKNG, BWA, BXP, BSX, BMY, AVGO, BR, BRO, BF.B, CHRW, CDNS, CZR, CPB, COF, CAH, KMX, CCL, CARR, CTLT, CAT, CBOE, CBRE, CDW, CE, CNC, CNP, CDAY, CF, CRL, SCHW, CHTR, CVX, CMG, CB, CHD, CI, CINF, CTAS, CSCO, C, CFG, CLX, CME, CMS, KO, CTSH, CL, CMCSA, CMA, CAG, COP, ED, STZ, CPRT, GLW, CTVA, COST, CTRA, CCI, CSX, CMI, CVS, DHI, DHR, DRI, DVA, DE, DAL, XRAY, DVN, DXCM, FANG, DLR, DFS, DIS, DG, DLTR, D, DPZ, DOV, DOW, DTE, DUK, DD, DXC, EMN, ETN, EBAY, ECL, EIX, EW, EA, ELV, LLY, EMR, ENPH, ETR, EOG, EPAM, EQT, EFX, EQIX, EQR, ESS, EL, ETSY, EG, EVRG, ES, EXC, EXPE, EXPD, EXR, XOM, FFIV, FDS, FAST, FRT, FDX, FITB, FSLR, FE, FIS, FISV, FLT, FMC, F, FTNT, FTV, FOXA, FOX, BEN, FCX, GRMN, IT, GE, GEN, GNRC, GD, GIS, GM, GPC, GILD, GL, GPN, GS, HAL, HIG, HAS, HCA, PEAK, HSIC, HES, HPE, HLT, HOLX, HD, HON, HRL, HST, HWM, HPQ, HUM, HBAN, HII, IBM, IEX, IDXX, ITW, ILMN, INCY, IR, INTC, ICE, IP, IPG, IFF, INTU, ISRG, IVZ, INVH, IQV, IRM, JBHT, JKHY, J, JNJ, JCI, JPM, JNPR, K, KDP, KEY, KEYS, KMB, KIM, KMI, KLAC, KHC, KR, LHX, LH, LRCX, LW, LVS, LDOS, LEN, LNC, LIN, LYV, LKQ, LMT, L, LOW, LUMN, LYB, MTB, MRO, MPC, MKTX, MAR, MMC, MLM, MAS, MA, MTCH, MKC, MCD, MCK, MDT, MRK, META, MET, MTD, MGM, MCHP, MU, MSFT, MAA, MRNA, MHK, MOH, TAP, MDLZ, MPWR, MNST, MCO, MS, MOS, MSI, MSCI, NDAQ, NTAP, NFLX, NWL, NEM, NWSA, NWS, NEE, NKE, NI, NDSN, NSC, NTRS, NOC, NCLH, NRG, NUE, NVDA, NVR, NXPI, ORLY, OXY, ODFL, OMC, ON, OKE, ORCL, OGN, OTIS, PCAR, PKG, PANW, PARA, PH, PAYX, PAYC, PYPL, PNR, PEP, PFE, PCG, PM, PSX, PNW, PXD, PNC, POOL, PPG, PPL, PFG, PG, PGR, PLD, PRU, PEG, PTC, PSA, PHM, QRVO, PWR, QCOM, DGX, RL, RJF, RTX, O, REG, REGN, RF, RSG, RMD, RVTY, RHI, ROK, ROL, ROP, ROST, RCL, SPGI, CRM, SBAC, SLB, STX, SEE, SRE, NOW, SHW, SPG, SWKS, SJM, SNA, SEDG, SO, LUV, SWK, SBUX, STT, STLD, STE, SYK, SYF, SNPS, SYY, TMUS, TROW, TTWO, TPR, TRGP, TGT, TEL, TDY, TFX, TER, TSLA, TXN, TXT, TMO, TJX, TSCO, TT, TDG, TRV, TRMB, TFC, TYL, TSN, USB, UDR, ULTA, UNP, UAL, UPS, URI, UNH, UHS, VLO, VTR, VRSN, VRSK, VZ, VRTX, VFC, VTRS, VICI, V, VMC, WAB, WBA, WMT, WBD, WM, WAT, WEC, WFC, WELL, WST, WDC, WRK, WY, WHR, WMB, WTW, GWW, WYNN, XEL, XYL, YUM, ZBRA, ZBH, ZION, ZTS
# Загружаем и преобразуем исторические данные...
# [*********************100%***********************]  490 of 490 completed
#
# 11 Failed downloads:
# ['FLT', 'FISV', 'PEAK', 'ABC', 'PXD', 'CDAY', 'CTLT', 'MRO', 'WRK', 'BRK.B']: YFPricesMissingError('possibly delisted; no price data found  (period=10y) (Yahoo error = "No data found, symbol may be delisted")')
# ['BF.B']: YFPricesMissingError('possibly delisted; no price data found  (period=10y)')
# Успешно загружены и преобразованы данные:
# Price       Date       Open       High        Low      Close     Volume  \
# 22635 2015-05-15  38.821192  38.931740  38.683007  38.729069  2147400.0
# 22636 2015-05-18  38.738276  39.337085  38.673789  39.272598  1966100.0
# 22637 2015-05-19  38.296083  39.456852  38.231597  39.033077  5277300.0
# 22638 2015-05-20  39.152847  39.466070  39.088361  39.254185  2652300.0
# 22639 2015-05-21  39.217314  39.364713  38.876455  38.987003  2126300.0
#
# Price symbol  Adj Close  future_price  future_month_price  annual_return  \
# 22635      A        NaN     39.996502           36.407551       0.032726
# 22636      A        NaN     41.365742           36.656269       0.053298
# 22637      A        NaN     41.281898           36.481232       0.057613
# 22638      A        NaN     41.505459           36.757614       0.057351
# 22639      A        NaN     41.812828           36.379894       0.072481
#
# Price  month_return
# 22635     -0.059943
# 22636     -0.066620
# 22637     -0.065376
# 22638     -0.063600
# 22639     -0.066871
# Данные сохранены в файл: sp500_ml_ready_20250515_151550.csv

# %% [markdown]
# Target - доходность через год от текущей даты

# %%
import pandas as pd
df = pd.read_csv("data/sp500_ml_ready_20250515_151550.csv")
df.head()
# Out:
#         Date       Open       High        Low      Close     Volume symbol  \
# 0 2015-05-15  38.821192  38.931740  38.683007  38.729069  2147400.0      A
# 1 2015-05-18  38.738276  39.337085  38.673789  39.272598  1966100.0      A
# 2 2015-05-19  38.296083  39.456852  38.231597  39.033077  5277300.0      A
# 3 2015-05-20  39.152847  39.466070  39.088361  39.254185  2652300.0      A
# 4 2015-05-21  39.217314  39.364713  38.876455  38.987003  2126300.0      A
#
#    Adj Close  future_price  future_month_price  annual_return  month_return
# 0        NaN     39.996502           36.407551       0.032726     -0.059943
# 1        NaN     41.365742           36.656269       0.053298     -0.066620
# 2        NaN     41.281898           36.481232       0.057613     -0.065376
# 3        NaN     41.505459           36.757614       0.057351     -0.063600
# 4        NaN     41.812828           36.379894       0.072481     -0.066871

# %%
import pandas_ta as ta
def add_ta_indicators_short_term(group):
    group = group.sort_values('Date')

    # Трендовые индикаторы (EMA, MACD)
    group.ta.ema(length=9, append=True, col_names=('EMA_9',))
    group.ta.ema(length=20, append=True, col_names=('EMA_20',))
    group.ta.macd(fast=12, slow=26, signal=9, append=True, col_names=('MACD_', 'MACD_hist_', 'MACD_signal_'))

    # Осцилляторы (RSI, Stochastic, CCI)
    group.ta.rsi(length=7, append=True, col_names=('RSI_7',))  # Более чувствительный RSI
    group.ta.rsi(length=14, append=True, col_names=('RSI_14',))
    group.ta.stoch(append=True, col_names=('STOCH_k_', 'STOCH_d_'))
    group.ta.cci(length=14, append=True, col_names=('CCI_14',))

    # Волатильность (ATR, Bollinger Bands)
    group.ta.atr(length=10, append=True, col_names=('ATR_10',))  # Более короткий период

    return group

# Применяем к данным
df_with_ta = df.groupby('symbol').apply(add_ta_indicators_short_term)

df_with_ta.drop("Adj Close", axis=1, inplace=True)
# Удаляем NaN (если индикаторы их создали)
df_with_ta = df_with_ta.reset_index(drop=True)\
             .dropna()

df_with_ta['Date'] = pd.to_datetime(df_with_ta['Date'])

# %%
df_with_ta
# Out:
#               Date        Open        High         Low       Close     Volume  \
# 33      2015-07-02   36.350895   36.609488   36.156951   36.554077  2160800.0
# 34      2015-07-06   36.120019   36.627970   36.092314   36.350906  2509400.0
# 35      2015-07-07   36.507907   36.748032   36.147723   36.748032  2927800.0
# 36      2015-07-08   36.461735   36.461735   35.750601   35.787544  3391000.0
# 37      2015-07-09   36.267786   36.323201   35.935308   35.944542  2237900.0
# ...            ...         ...         ...         ...         ...        ...
# 1232093 2024-05-06  165.497718  165.764719  163.055056  164.113205  3081300.0
# 1232094 2024-05-07  165.112042  170.323701  164.627460  166.585541  3337500.0
# 1232095 2024-05-08  165.230700  165.646050  159.217994  163.094604  4673100.0
# 1232096 2024-05-09  163.964876  166.526206  163.094611  166.269089  2145300.0
# 1232097 2024-05-10  166.842687  168.108519  166.427323  167.169022  2010700.0
#
#         symbol  future_price  future_month_price  annual_return  ...  \
# 33           A     41.652184           37.819344       0.139468  ...
# 34           A     40.858356           37.865509       0.123998  ...
# 35           A     41.530762           37.514584       0.130149  ...
# 36           A     41.484066           37.606934       0.159176  ...
# 37           A     42.474007           37.052799       0.181654  ...
# ...        ...           ...                 ...            ...  ...
# 1232093    ZTS    161.690002          169.977570      -0.014765  ...
# 1232094    ZTS    159.270004          173.873962      -0.043915  ...
# 1232095    ZTS    161.919998          174.823334      -0.007202  ...
# 1232096    ZTS    160.410004          174.961792      -0.035239  ...
# 1232097    ZTS    154.919998          176.850662      -0.073273  ...
#
#              EMA_20     MACD_  MACD_hist_  MACD_signal_      RSI_7     RSI_14  \
# 33        36.850444 -0.612101    0.079867     -0.691969  50.249128  44.761838
# 34        36.802869 -0.579963    0.089605     -0.669568  46.134470  42.707166
# 35        36.797646 -0.516495    0.122458     -0.638953  54.610190  47.755268
# 36        36.701446 -0.537503    0.081160     -0.618663  37.818862  38.841310
# 37        36.629360 -0.535313    0.066680     -0.601993  41.262932  40.786909
# ...             ...       ...         ...           ...        ...        ...
# 1232093  158.227316 -0.767665    2.580082     -3.347748  69.895544  57.255251
# 1232094  159.023337 -0.061734    2.628811     -2.690545  74.225205  60.293647
# 1232095  159.411077  0.213571    2.323292     -2.109722  60.008019  54.412288
# 1232096  160.064221  0.680066    2.231830     -1.551764  66.762198  58.387380
# 1232097  160.740869  1.109594    2.129086     -1.019493  68.520568  59.466416
#
#           STOCH_k_   STOCH_d_      CCI_14    ATR_10
# 33       33.973509  24.610816  -13.321123  0.647886
# 34       47.451993  32.162365  -36.571277  0.636342
# 35       56.564186  45.996563   16.623668  0.632646
# 36       42.294775  48.770318 -110.128065  0.669965
# 37       34.730089  44.529684  -78.728661  0.656257
# ...            ...        ...         ...       ...
# 1232093  83.505294  79.793427  105.316247  4.914747
# 1232094  82.564039  81.973106  113.281466  5.044322
# 1232095  79.407841  81.825725   59.666681  5.276645
# 1232096  81.540893  81.170924   77.208195  5.092140
# 1232097  82.203429  81.050721   87.670311  4.766869
#
# [1056670 rows x 22 columns]

# %%
df_with_ta.to_csv("data/stocks_with_indicators_months_sp490.csv",
                  index=0)
